# %%
from pygooglenews import GoogleNews
from newspaper import Article
import pymongo

from newspaper import Config
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0'
config = Config()
config.browser_user_agent = user_agent

mongourl = 'mongodb+srv://alaxhenry:Tmdcjdahzk123@alaxhenry.3bowh.mongodb.net/?retryWrites=true&w=majority'

myclient = pymongo.MongoClient('mongodb+srv://alaxhenry:Tmdcjdahzk123@alaxhenry.3bowh.mongodb.net/?retryWrites=true&w=majority')
my_database = myclient["AlexandroHenryDB"]  
google_news = my_database["google_news"] 

gn = GoogleNews(country='US')

business = gn.topic_headlines('BUSINESS', proxies=None, scraping_bee = None)
links = []

for item in business['entries']:
    links.append(item['link'])



for item in links:
    try:
        a = Article(item, language='ko', config=config)
        a.download()
        a.parse()
    except:
        pass


    
    data = {'title': a.title, 'text': a.text, 'publishedAt': a.publish_date, 'link': item, 'publisher': a.authors, 'topic': 'finance', 'keyword': a.keywords, 'tags': a.tags, 'summary': a.summary}
    print(data)
    # google_news.insert_one(data)
# Out:
# {'title': 'Gasoline prices top $5 a gallon nationally for the first time and are likely headed higher', 'text': '', 'publishedAt': datetime.datetime(2022, 6, 11, 12, 5, 22, tzinfo=tzutc()), 'link': 'https://news.google.com/__i/rss/rd/articles/CBMifmh0dHBzOi8vd3d3LmNuYmMuY29tLzIwMjIvMDYvMTEvZ2Fzb2xpbmUtcHJpY2VzLXRvcC01LWEtZ2FsbG9uLW5hdGlvbmFsbHktZm9yLXRoZS1maXJzdC10aW1lLWFuZC1hcmUtbGlrZWx5LWhlYWRlZC1oaWdoZXIuaHRtbNIBAA?oc=5', 'publisher': ['Patti Domm', 'In'], 'topic': 'finance', 'keyword': [], 'tags': set(), 'summary': ''}
# {'title': 'Here’s What You Need to Know About America’s Super-Hot Inflation', 'text': '', 'publishedAt': datetime.datetime(2022, 6, 11, 9, 0, 24, 474000, tzinfo=tzutc()), 'link': 'https://news.google.com/__i/rss/rd/articles/CBMiV2h0dHBzOi8vd3d3Lm55dGltZXMuY29tLzIwMjIvMDYvMTEvYnVzaW5lc3MvZWNvbm9teS9pbmZsYXRpb24tdW5pdGVkLXN0YXRlcy1wcmljZXMuaHRtbNIBAA?oc=5', 'publisher': ['Jeanna Smialek'], 'topic': 'finance', 'keyword': [], 'tags': set(), 'summary': ''}
# ...

# %%
search = gn.search('')

# %%
# Out:
# https://news.google.com/__i/rss/rd/articles/CBMifmh0dHBzOi8vd3d3LmNuYmMuY29tLzIwMjIvMDYvMTEvZ2Fzb2xpbmUtcHJpY2VzLXRvcC01LWEtZ2FsbG9uLW5hdGlvbmFsbHktZm9yLXRoZS1maXJzdC10aW1lLWFuZC1hcmUtbGlrZWx5LWhlYWRlZC1oaWdoZXIuaHRtbNIBAA?oc=5
# https://news.google.com/__i/rss/rd/articles/CBMiZWh0dHBzOi8vbnlwb3N0LmNvbS8yMDIyLzA2LzEwL2luZmxhdGlvbi1oYW1tZXJzLW5ldy15b3JrZXJzLWFzLWNvbnN1bWVyLXByaWNlcy1zdXJnZS10by00MC15ZWFyLWhpZ2gv0gEA?oc=5
# https://news.google.com/__i/rss/rd/articles/CBMiaGh0dHBzOi8vd3d3LmludmVzdG9ycy5jb20vbmV3cy9lY29ub215L2NwaS1pbmZsYXRpb24tcmF0ZS1zaG9jay1uZXctNDAteWVhci1oaWdoLWRvdy1qb25lcy1mdXR1cmVzLWZhbGwv0gEA?oc=5
# https://news.google.com/__i/rss/rd/articles/CBMiK2h0dHBzOi8vd3d3LnlvdXR1YmUuY29tL3dhdGNoP3Y9MlVxdEJaRE5lQ0nSAQA?oc=5
# https://news.google.com/__i/rss/rd/articles/CBMicmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2J1c2luZXNzL2F1dG9zLXRyYW5zcG9ydGF0aW9uL3Rlc2xhLXNlZWstaW52ZXN0b3ItYXBwcm92YWwtMy1mb3ItMS1zdG9jay1zcGxpdC0yMDIyLTA2LTEwL9IBAA?oc=5
# ...
