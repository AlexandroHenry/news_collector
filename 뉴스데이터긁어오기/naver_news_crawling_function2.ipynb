# %%
from selenium import webdriver
from newspaper import Article
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import pymongo
from datetime import datetime
from datetime import timedelta
from tqdm import tqdm

mongourl = 'mongodb+srv://alaxhenry:Tmdcjdahzk123@alaxhenry.3bowh.mongodb.net/?retryWrites=true&w=majority'

myclient = pymongo.MongoClient('mongodb+srv://alaxhenry:Tmdcjdahzk123@alaxhenry.3bowh.mongodb.net/?retryWrites=true&w=majority')
my_database = myclient["AlexandroHenryDB"]  
naver_news = my_database["news_kr"] 

options = Options()
options.add_argument("start-maximized")
options.add_experimental_option('excludeSwitches', ['enable-logging'])
options.add_argument("--disable-infobars")
options.add_argument("start-maximized")
options.add_argument("--disable-extensions")
# options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")
options.add_argument("--disable-notifications")

def naver_finance(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=259&sid1=101&mid=shm&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=259&sid1=101&mid=shm&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_finance'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_finance' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_stock(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=258&sid1=101&mid=shm&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=258&sid1=101&mid=shm&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_stock'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_stock' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_global_econ(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=262&mid=shm&sid1=101&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=262&mid=shm&sid1=101&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_global'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_global' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_realEstate(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=260&sid1=101&mid=shm&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=260&sid1=101&mid=shm&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_realestate'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_realestate' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_venture(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=771&sid1=101&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=771&sid1=101&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_venture'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_venture' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_industry(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=261&sid1=101&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=261&sid1=101&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_industry'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_industry' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_life_econ(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=310&sid1=101&mid=shm&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=310&sid1=101&mid=shm&date=20220613&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_life'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_life' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_general_econ(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=263&sid1=101&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=263&sid1=101&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_general'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'econ_general' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_world_america(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=232&sid1=104&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=232&sid1=104&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'world_america'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'world_america' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_world_europe(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=233&sid1=104&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=233&sid1=104&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'world_europe'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'world_europe' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_world_mideast(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=234&mid=shm&sid1=104&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=234&mid=shm&sid1=104&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'world_mideast'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'world_mideast' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_world_asia(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=231&sid1=104&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=231&sid1=104&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'world_asia'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'world_asia' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_world_general(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=322&sid1=104&mid=shm&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=322&sid1=104&mid=shm&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'world_general'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'world_general' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_it_mobile(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=731&sid1=105&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=731&sid1=105&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_mobile'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_mobile' }
            naver_news.insert_one(data)
    
    driver.close() 

def naver_it_internet_sns(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=226&sid1=105&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=226&sid1=105&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_internet_sns'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_internet_sns' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_it_communication_new_media(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=227&sid1=105&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=227&sid1=105&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_communication'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_communication' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_it_general(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=230&sid1=105&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=230&sid1=105&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_general'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_general' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_it_security_hacking(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=732&sid1=105&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=732&sid1=105&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_security'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_security' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_it_computer(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=283&sid1=105&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=283&sid1=105&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_computer'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_computer' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_it_game(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=229&sid1=105&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=229&sid1=105&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_game'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'it_game' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_it_general_science(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=228&sid1=105&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=228&sid1=105&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'general_science'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'general_science' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_politic_diplomacy(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=267&sid1=100&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=267&sid1=100&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'diplomacy'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'diplomacy' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_politic_national_defence(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=267&sid1=100&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=267&sid1=100&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'politic_nationaldefence'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'politic_nationaldefence' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_politic_general(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=269&sid1=100&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=269&sid1=100&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'politic_general'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'politic_general' }
            naver_news.insert_one(data)
    
    driver.close()

def naver_society_labor(today):
    driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
    url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=251&sid1=102&mid=shm&date={today}&page=1'
    driver.get(url)

    try:
        for i in range(200):
            driver.find_element(By.LINK_TEXT, '다음').click()
    except:
        pass

    pagination = driver.find_element(By.XPATH, '(//*[@id="main_content"]/div[3])[last()]')

    pages = int(pagination.text[-2:])

    for i in range(pages):
        url = f'https://news.naver.com/main/list.naver?mode=LS2D&sid2=251&sid1=102&mid=shm&date={today}&page={i+1}'
        driver.get(url)

        for j in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt[2]/a').get_attribute('href')
                                                       
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{j+1}]/dl/dd/span[2]').text

            time = driver.find_element(By.CLASS_NAME, f'date').text
            
            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':

                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'society_labor'}
            naver_news.insert_one(data)
        for k in range(10):
            try:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt[2]/a').get_attribute('href')
            except:
                link = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[2]/li[{k+1}]/dl/dt/a').get_attribute('href')

            publisher = driver.find_element(By.XPATH, f'/html/body/div[1]/table/tbody/tr/td[2]/div/div[2]/ul[1]/li[{k+1}]/dl/dd/span[2]').text
            
            time = driver.find_element(By.CLASS_NAME, f'date').text

            if time[-3:] == '시간전':
                current =  datetime.now()
            
                minus_time = int(time[0])

                publishedAt = current - timedelta(hours=minus_time)

                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            elif time[-2:] == '분전':
                minus_time = int(time[0])
                
                publishedAt = current - timedelta(minutes=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")
            
            elif time[-2:] == '일전':
                current =  datetime.now()
                minus_time = int(time[0])
        
                publishedAt = current - timedelta(days=minus_time)
                publishedAt = publishedAt.strftime("%Y-%m-%d-%H-%M-%S")

            else:
                publishedAt = time

            a = Article(link, language='ko')
            a.download()
            a.parse()
            
            data = {'title': a.title, 'text': a.text, 'publishedAt': publishedAt, 'link': link, 'publisher': publisher, 'topic': 'society_labor' }
            naver_news.insert_one(data)
    
    driver.close()

# %%
today = 20220612

try:
    naver_finance(today)
except:
    pass

try:  
    naver_stock(today)
except:
    pass

try:
    naver_global_econ(today)
except:
    pass

try:
    naver_realEstate(today)
except:
    pass

try:
    naver_venture(today)
except:
    pass

try:
    naver_industry(today)
except:
    pass

try:
    naver_life_econ(today)
except:
    pass

try:
    naver_general_econ(today)
except:
    pass

try:
    naver_world_america(today)
except:
    pass

try:
    naver_world_europe(today)
except:
    pass

try:
    naver_world_mideast(today)
except:
    pass

try:
    naver_world_asia(today)
except:
    pass

try:
    naver_world_general(today)
except:
    pass

try:
    naver_it_mobile(today)
except:
    pass

try:
    naver_it_internet_sns(today)
except:
    pass

try:
    naver_it_communication_new_media(today)
except:
    pass

try:
    naver_it_general(today)
except:
    pass

try:
    naver_it_security_hacking(today)
except:
    pass

try:
    naver_it_computer(today)
except:
    pass

try:
    naver_it_game(today)
except:
    pass

try:
    naver_it_general_science(today)
except:
    pass

try:
    naver_politic_diplomacy(today)
except:
    pass

try:
    naver_politic_national_defence(today)
except:
    pass

try:
    naver_politic_general(today)
except:
    pass

try:
    naver_society_labor(today)
except:
    pass
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/seungchulha/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# /var/folders/rb/h6n7qs_j0kbbr6p3447bl73w0000gn/T/ipykernel_8332/3639890150.py:30: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
# ---------------------------------------------------------------------------
# ArticleException                          Traceback (most recent call last)
# /Users/seungchulha/Developer/python/주식분석GUI/naver_news_crawling_function2.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/seungchulha/Developer/python/%EC%A3%BC%EC%8B%9D%EB%B6%84%EC%84%9DGUI/naver_news_crawling_function2.ipynb#ch0000001?line=0'>1</a> naver_finance(20220607)
#
# ...
